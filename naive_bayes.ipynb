# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
data = pd.read_csv("dataset.csv")

#erase redundant records
data = data.head(400)

# Remove unnecessary columns (e.g., those with 'Unnamed')
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# Split columns into symptoms and diseases
symptom_columns = data.columns[:131]  # Symptoms are the first 131 columns
disease_column = data['prognosis']  # Assuming 'prognosis' column represents diseases

# Transform the symptom columns to Boolean (True for 1, False for 0)
X = data[symptom_columns].replace({0: False, 1: True}).astype(int)  # Features
y = disease_column  # Target (Disease)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# Initialize the Naive Bayes classifier
model = MultinomialNB()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy * 100:.2f}%")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# (40,)
#
# Accuracy: 80.00%
#
# Classification Report:
#                                precision    recall  f1-score   support
#
#                          AIDS       1.00      1.00      1.00         7
#                          Acne       1.00      1.00      1.00         8
#           Alcoholic Hepatitis       1.00      1.00      1.00         8
#                       Allergy       1.00      0.62      0.77         8
#                     Arthritis       1.00      1.00      1.00         7
#              Bronchial Asthma       1.00      1.00      1.00         7
#          Cervical Spondylosis       1.00      1.00      1.00         8
#                    Chickenpox       1.00      1.00      1.00         5
#           Chronic Cholestasis       0.00      0.00      0.00         8
#                   Common Cold       0.62      1.00      0.77         5
#                        Dengue       1.00      1.00      1.00         8
# ...
