# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules

# Load the dataset
data = pd.read_csv("dataset.csv")

# Remove unnecessary columns (e.g., those with 'Unnamed')
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
data = data.drop(columns='prognosis')

# Limit to the first 131 columns only
symptom_columns = data.columns[:132]  # First 131 columns are symptoms
data = data[symptom_columns]

# Transform the symptom columns to Boolean (True for 1, False for 0)
data = data.replace({0: False, 1: True})

# Perform Apriori algorithm
frequent_itemsets = apriori(data, min_support=0.1, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, 4,metric="confidence", min_threshold=0.8)
rules = rules[(rules['lift'] >= 4) & (rules['leverage'] > 0.05)]

# Group rules by antecedent size
k1_rules = rules[rules['antecedents'].apply(lambda x: len(x) == 1)]
k2_rules = rules[rules['antecedents'].apply(lambda x: len(x) == 2)]
k3_rules = rules[rules['antecedents'].apply(lambda x: len(x) == 3)]
k4_rules = rules[rules['antecedents'].apply(lambda x: len(x) == 4)]

#rules.to_excel("new_rules.xlsx", index=False)

# %%
k1_rules
# Out:
#             antecedents                       consequents  antecedent support  \
# 4          (dark_urine)                  (yellowish_skin)            0.115904
# 6   (yellowing_of_eyes)                  (yellowish_skin)            0.165894
# 7          (dark_urine)                  (abdominal_pain)            0.115904
# 8   (yellowing_of_eyes)                (loss_of_appetite)            0.165894
# 21         (dark_urine)  (abdominal_pain, yellowish_skin)            0.115904
#
#     consequent support   support  confidence      lift  representativity  \
# 4             0.185446  0.109857    0.947826  5.111049               1.0
# 6             0.185446  0.134247    0.809235  4.363709               1.0
# 7             0.209837  0.111066    0.958261  4.566698               1.0
# 8             0.234227  0.159847    0.963548  4.113736               1.0
# 21            0.155009  0.105019    0.906087  5.845380               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 4   0.088363   15.612276       0.909794  0.573684   0.935948    0.770109
# 6   0.103483    4.269921       0.924148  0.618384   0.765804    0.766574
# 7   0.086745   18.930995       0.883415  0.517371   0.947177    0.743780
# 8   0.120990   21.007707       0.907453  0.665268   0.952398    0.822996
# 21  0.087053    8.997589       0.937596  0.633050   0.888859    0.791795

# %%
k2_rules
# Out:
#                               antecedents  \
# 14             (vomiting, yellowish_skin)
# 16          (vomiting, yellowing_of_eyes)
# 18           (yellowing_of_eyes, fatigue)
# 19           (abdominal_pain, dark_urine)
# 20           (dark_urine, yellowish_skin)
# 22               (nausea, yellowish_skin)
# 23            (yellowing_of_eyes, nausea)
# 24               (nausea, yellowish_skin)
# 25    (yellowing_of_eyes, yellowish_skin)
# 26  (yellowing_of_eyes, loss_of_appetite)
# 27     (yellowish_skin, loss_of_appetite)
# 28    (abdominal_pain, yellowing_of_eyes)
# 30            (yellowing_of_eyes, nausea)
# 31    (abdominal_pain, yellowing_of_eyes)
# 32     (abdominal_pain, loss_of_appetite)
# 36            (yellowing_of_eyes, nausea)
# 37               (nausea, yellowish_skin)
# 42    (abdominal_pain, yellowing_of_eyes)
#
#                               consequents  antecedent support  \
# 14                       (abdominal_pain)            0.131828
# 16                     (loss_of_appetite)            0.113485
# 18                     (loss_of_appetite)            0.112276
# 19                       (yellowish_skin)            0.111066
# 20                       (abdominal_pain)            0.109857
# 22                     (loss_of_appetite)            0.109857
# 23                       (yellowish_skin)            0.111066
# 24                    (yellowing_of_eyes)            0.109857
# 25                     (loss_of_appetite)            0.134247
# 26                       (yellowish_skin)            0.159847
# 27                    (yellowing_of_eyes)            0.133038
# 28                       (yellowish_skin)            0.114695
# 30                     (loss_of_appetite)            0.111066
# 31                     (loss_of_appetite)            0.114695
# 32                    (yellowing_of_eyes)            0.133038
# 36     (yellowish_skin, loss_of_appetite)            0.111066
# 37  (yellowing_of_eyes, loss_of_appetite)            0.109857
# 42     (yellowish_skin, loss_of_appetite)            0.114695
#
#     consequent support   support  confidence      lift  representativity  \
# 14            0.209837  0.125781    0.954128  4.547004               1.0
# 16            0.234227  0.109857    0.968028  4.132865               1.0
# 18            0.234227  0.108647    0.967684  4.131395               1.0
# 19            0.185446  0.105019    0.945554  5.098795               1.0
# 20            0.209837  0.105019    0.955963  4.555748               1.0
# 22            0.234227  0.105019    0.955963  4.081355               1.0
# 23            0.185446  0.105019    0.945554  5.098795               1.0
# 24            0.165894  0.105019    0.955963  5.762496               1.0
# 25            0.234227  0.128200    0.954955  4.077050               1.0
# 26            0.185446  0.128200    0.802018  4.324793               1.0
# 27            0.165894  0.128200    0.963636  5.808748               1.0
# 28            0.185446  0.108647    0.947276  5.108082               1.0
# 30            0.234227  0.106229    0.956443  4.083402               1.0
# 31            0.234227  0.109857    0.957821  4.089285               1.0
# 32            0.165894  0.109857    0.825758  4.977623               1.0
# 36            0.133038  0.100181    0.901996  6.780006               1.0
# 37            0.159847  0.100181    0.911927  5.705004               1.0
# 42            0.133038  0.103810    0.905097  6.803310               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 14  0.098119   17.225559       0.898526  0.582633   0.941947    0.776776
# 16  0.083276   23.951679       0.855075  0.461864   0.958249    0.718524
# 18  0.082349   23.696421       0.853814  0.456780   0.957800    0.715770
# 19  0.084422   14.960633       0.904314  0.548421   0.933158    0.755929
# 20  0.081967   17.943291       0.876822  0.489202   0.944269    0.728222
# 22  0.079288   17.389429       0.848159  0.439292   0.942494    0.702164
# 23  0.084422   14.960633       0.904314  0.548421   0.933158    0.755929
# 24  0.086795   18.941158       0.928462  0.615112   0.947205    0.794507
# 25  0.096756   17.000161       0.871755  0.533557   0.941177    0.751144
# 26  0.098557    4.114273       0.915042  0.590529   0.756944    0.746661
# 27  0.106130   22.937916       0.954881  0.750885   0.956404    0.868209
# 28  0.087378   15.449365       0.908423  0.567368   0.935272    0.766573
# 30  0.080214   17.580872       0.849452  0.444351   0.943120    0.704986
# 31  0.082992   18.155202       0.853331  0.459528   0.944919    0.713420
# 32  0.087787    4.787043       0.921725  0.581023   0.791103    0.743984
# 36  0.085405    8.846226       0.959023  0.696078   0.886957    0.827513
# 37  0.082621    9.539239       0.926497  0.590963   0.895170    0.769330
# 42  0.088551    9.135214       0.963524  0.721289   0.890533    0.842700

# %%
k3_rules
# Out:
#                                           antecedents          consequents  \
# 33        (yellowing_of_eyes, nausea, yellowish_skin)   (loss_of_appetite)
# 34      (yellowing_of_eyes, nausea, loss_of_appetite)     (yellowish_skin)
# 35         (nausea, yellowish_skin, loss_of_appetite)  (yellowing_of_eyes)
# 38  (abdominal_pain, yellowing_of_eyes, yellowish_...   (loss_of_appetite)
# 39  (abdominal_pain, yellowing_of_eyes, loss_of_ap...     (yellowish_skin)
# 40  (abdominal_pain, yellowish_skin, loss_of_appet...  (yellowing_of_eyes)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 33            0.105019            0.234227  0.100181    0.953935  4.072694
# 34            0.106229            0.185446  0.100181    0.943074  5.085424
# 35            0.105019            0.165894  0.100181    0.953935  5.750268
# 38            0.108647            0.234227  0.103810    0.955473  4.079262
# 39            0.109857            0.185446  0.103810    0.944954  5.095562
# 40            0.106229            0.165894  0.103810    0.977230  5.890688
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 33               1.0  0.075583   16.623656       0.842993  0.419056
# 34               1.0  0.080482   14.308990       0.898842  0.523158
# 35               1.0  0.082759   18.107052       0.923031  0.586777
# 38               1.0  0.078362   17.197986       0.846868  0.434233
# 39               1.0  0.083437   14.797722       0.902946  0.542105
# 40               1.0  0.086187   36.631156       0.928918  0.616766
#
#     certainty  kulczynski
# 33   0.939845    0.690823
# 34   0.930114    0.741646
# 35   0.944773    0.778911
# 38   0.941854    0.699337
# 39   0.932422    0.752368
# 40   0.972701    0.801495

# %%
k4_rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
